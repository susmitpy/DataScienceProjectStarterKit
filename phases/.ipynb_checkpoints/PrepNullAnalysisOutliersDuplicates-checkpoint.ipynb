# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from utils.common_transformers import NullPct, OutlierDetector, IsNull, DTypeTransformer

from sklearn.feature_selection import VarianceThreshold

import altair as alt
from altair import Chart,X,Y

alt.data_transformers.disable_max_rows()

from sklearn.base import TransformerMixin,BaseEstimator

from common import display_dtypes, display_side_by_side

# %% [markdown]
# # Remove Duplicates

# %%
df = pd.read_csv("../data/data.csv")

# %%
duplicated = df[df.duplicated()]
df.drop(duplicated.index,inplace=True)

display(duplicated)
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked]
# Index: []

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
display_dtypes(df,num_rows_per_column=5)
# Out:
# DTypes
# <table style="display:inline;padding:12px;margin:6px;padding-top:10px;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>PassengerId</th>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>Survived</th>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>Pclass</th>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>Name</th>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>Sex</th>
#       <td>object</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding:12px;margin:6px;padding-top:10px;"><table style="display:inline;padding:12px;margin:6px;padding-top:10px;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Age</th>
#       <td>float64</td>
#     </tr>
#     <tr>
#       <th>SibSp</th>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>Parch</th>
#       <td>int64</td>
#     </tr>
#     <tr>
#       <th>Ticket</th>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>Fare</th>
#       <td>float64</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding:12px;margin:6px;padding-top:10px;"><table style="display:inline;padding:12px;margin:6px;padding-top:10px;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>0</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Cabin</th>
#       <td>object</td>
#     </tr>
#     <tr>
#       <th>Embarked</th>
#       <td>object</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding:12px;margin:6px;padding-top:10px;">

# %%
df = DTypeTransformer({"Survived":"bool","Pclass":"category","Sex":"category","Cabin":"category","Embarked":"category"}).fit_transform(df)

# %% [markdown]
# # Outliers

# %%
df = OutlierDetector().fit_transform(df)

# %%
cols = [i for i in df.columns if i.endswith("_is_outlier")]
cols = [i for i in cols if max(df[i])]
cols += [i[:-11] for i in cols]
outlier_cols = [i for i in cols if i.endswith("_is_outlier")]

# %%
outlier_cols
# Out:
# ['Age_is_outlier', 'SibSp_is_outlier', 'Parch_is_outlier', 'Fare_is_outlier']

# %%
display_side_by_side([df[cols].query(" or ".join(outlier_cols)).sample(10) for i in range(2)])
# Out:
# <table style="display:inline;padding:12px;margin:6px;padding-top:10px;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age_is_outlier</th>
#       <th>SibSp_is_outlier</th>
#       <th>Parch_is_outlier</th>
#       <th>Fare_is_outlier</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>272</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>41.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>19.5000</td>
#     </tr>
#     <tr>
#       <th>54</th>
#       <td>True</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>65.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>61.9792</td>
#     </tr>
#     <tr>
#       <th>542</th>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>11.0</td>
#       <td>4</td>
#       <td>2</td>
#       <td>31.2750</td>
#     </tr>
#     <tr>
#       <th>634</th>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>9.0</td>
#       <td>3</td>
#       <td>2</td>
#       <td>27.9000</td>
#     </tr>
#     <tr>
#       <th>820</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>52.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>93.5000</td>
#     </tr>
#     <tr>
#       <th>888</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>NaN</td>
#       <td>1</td>
#       <td>2</td>
#       <td>23.4500</td>
#     </tr>
#     <tr>
#       <th>581</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>39.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>110.8833</td>
#     </tr>
#     <tr>
#       <th>167</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>45.0</td>
#       <td>1</td>
#       <td>4</td>
#       <td>27.9000</td>
#     </tr>
#     <tr>
#       <th>763</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>36.0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>120.0000</td>
#     </tr>
#     <tr>
#       <th>549</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>8.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>36.7500</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding:12px;margin:6px;padding-top:10px;"><table style="display:inline;padding:12px;margin:6px;padding-top:10px;" border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age_is_outlier</th>
#       <th>SibSp_is_outlier</th>
#       <th>Parch_is_outlier</th>
#       <th>Fare_is_outlier</th>
#       <th>Age</th>
#       <th>SibSp</th>
#       <th>Parch</th>
#       <th>Fare</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>290</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>26.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>78.8500</td>
#     </tr>
#     <tr>
#       <th>698</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>49.0</td>
#       <td>1</td>
#       <td>1</td>
#       <td>110.8833</td>
#     </tr>
#     <tr>
#       <th>642</th>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2.0</td>
#       <td>3</td>
#       <td>2</td>
#       <td>27.9000</td>
#     </tr>
#     <tr>
#       <th>479</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>12.2875</td>
#     </tr>
#     <tr>
#       <th>233</th>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>5.0</td>
#       <td>4</td>
#       <td>2</td>
#       <td>31.3875</td>
#     </tr>
#     <tr>
#       <th>52</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>49.0</td>
#       <td>1</td>
#       <td>0</td>
#       <td>76.7292</td>
#     </tr>
#     <tr>
#       <th>615</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>24.0</td>
#       <td>1</td>
#       <td>2</td>
#       <td>65.0000</td>
#     </tr>
#     <tr>
#       <th>155</th>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>False</td>
#       <td>51.0</td>
#       <td>0</td>
#       <td>1</td>
#       <td>61.3792</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>False</td>
#       <td>True</td>
#       <td>True</td>
#       <td>False</td>
#       <td>2.0</td>
#       <td>3</td>
#       <td>1</td>
#       <td>21.0750</td>
#     </tr>
#     <tr>
#       <th>385</th>
#       <td>False</td>
#       <td>False</td>
#       <td>False</td>
#       <td>True</td>
#       <td>18.0</td>
#       <td>0</td>
#       <td>0</td>
#       <td>73.5000</td>
#     </tr>
#   </tbody>
# </table style="display:inline;padding:12px;margin:6px;padding-top:10px;">

# %% [markdown]
# # Null and Outlier Analysis

# %%
df.columns
# Out:
# Index(['PassengerId', 'Survived', 'Pclass', 'Name', 'Sex', 'Age', 'SibSp',
#        'Parch', 'Ticket', 'Fare', 'Cabin', 'Embarked',
#        'PassengerId_is_outlier', 'Age_is_outlier', 'SibSp_is_outlier',
#        'Parch_is_outlier', 'Fare_is_outlier'],
#       dtype='object')

# %%
print("Columns")
pd.DataFrame(df.isnull().mean() * 100,columns=["NullPerc"]).query("NullPerc>0").sort_values("NullPerc")
# Out:
# Columns
#            NullPerc
# Embarked   0.224467
# Age       19.865320
# Cabin     77.104377

# %%
df = NullPct().fit_transform(df)

# %%
Chart(df).mark_bar().encode(
    Y("null_pct:N"),
    X("count(null_pct):Q")
)
# Out:
# alt.Chart(...)

# %%
df = IsNull(exclude=["PassengerId"],drop_original_col=False).fit_transform(df)

# %%
num_data = df.select_dtypes(include=[int,float,bool])
var_thresh = VarianceThreshold()
var_thresh.fit(num_data)
cols_removed = [j for i,j in enumerate(list(num_data.columns)) if not var_thresh.get_support()[i]]

print("Cols Removed: ", cols_removed)

df.drop(num_data.columns,axis=1,inplace=True)
df = pd.concat([df,num_data.iloc[:,var_thresh.get_support()]],axis=1)
df.head()
# Out:
# Cols Removed:  ['PassengerId_is_outlier', 'Survived_is_null', 'Pclass_is_null', 'Name_is_null', 'Sex_is_null', 'SibSp_is_null', 'Parch_is_null', 'Ticket_is_null', 'Fare_is_null']
#              Ticket Cabin                                               Name  \
# 0         A/5 21171   NaN                            Braund, Mr. Owen Harris
# 1          PC 17599   C85  Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2  STON/O2. 3101282   NaN                             Heikkinen, Miss. Laina
# 3            113803  C123       Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4            373450   NaN                           Allen, Mr. William Henry
#
#   Pclass Embarked     Sex  Age_is_outlier  Parch_is_outlier  Fare_is_outlier  \
# 0      3        S    male           False             False            False
# 1      1        C  female           False             False             True
# 2      3        S  female           False             False            False
# 3      1        S  female           False             False            False
# 4      3        S    male           False             False            False
#
#    SibSp     Fare  SibSp_is_outlier  PassengerId  null_pct  Parch   Age  \
# 0      1   7.2500             False            1      8.33      0  22.0
# 1      1  71.2833             False            2      0.00      0  38.0
# 2      0   7.9250             False            3      8.33      0  26.0
# 3      1  53.1000             False            4      0.00      0  35.0
# 4      0   8.0500             False            5      8.33      0  35.0
#
#    Survived  Age_is_null  Cabin_is_null  Embarked_is_null
# 0     False        False           True             False
# 1      True        False          False             False
# 2      True        False           True             False
# 3      True        False          False             False
# 4     False        False           True             False

# %%
null_cols = pd.DataFrame(df.isnull().sum(),columns=["Nulls"]).query("Nulls>0").index.to_list()
print("Rows where col value is null")

for col in null_cols:
    print("Column: " + col)
    display(df[df[col].isnull()])
# Out:
# Rows where col value is null
# Column: Age
#      PassengerId  Survived Pclass                                      Name  \
# 5              6     False      3                          Moran, Mr. James
# 17            18      True      2              Williams, Mr. Charles Eugene
# 19            20      True      3                   Masselmani, Mrs. Fatima
# 26            27     False      3                   Emir, Mr. Farred Chehab
# 28            29      True      3             O'Dwyer, Miss. Ellen "Nellie"
# ..           ...       ...    ...                                       ...
# 859          860     False      3                          Razi, Mr. Raihed
# 863          864     False      3         Sage, Miss. Dorothy Edith "Dolly"
# 868          869     False      3               van Melkebeke, Mr. Philemon
# 878          879     False      3                        Laleff, Mr. Kristo
# 888          889     False      3  Johnston, Miss. Catherine Helen "Carrie"
#
#         Sex  Age  SibSp  Parch      Ticket     Fare Cabin Embarked  \
# 5      male  NaN      0      0      330877   8.4583   NaN        Q
# 17     male  NaN      0      0      244373  13.0000   NaN        S
# 19   female  NaN      0      0        2649   7.2250   NaN        C
# 26     male  NaN      0      0        2631   7.2250   NaN        C
# 28   female  NaN      0      0      330959   7.8792   NaN        Q
# ..      ...  ...    ...    ...         ...      ...   ...      ...
# 859    male  NaN      0      0        2629   7.2292   NaN        C
# 863  female  NaN      8      2    CA. 2343  69.5500   NaN        S
# 868    male  NaN      0      0      345777   9.5000   NaN        S
# 878    male  NaN      0      0      349217   7.8958   NaN        S
# 888  female  NaN      1      2  W./C. 6607  23.4500   NaN        S
#
#      PassengerId_is_outlier  Age_is_outlier  SibSp_is_outlier  \
# 5                     False           False             False
# 17                    False           False             False
# 19                    False           False             False
# 26                    False           False             False
# 28                    False           False             False
# ..                      ...             ...               ...
# 859                   False           False             False
# 863                   False           False              True
# 868                   False           False             False
# 878                   False           False             False
# 888                   False           False             False
#
#      Parch_is_outlier  Fare_is_outlier  null_pct
# 5               False            False     16.67
# 17              False            False     16.67
# 19              False            False     16.67
# 26              False            False     16.67
# 28              False            False     16.67
# ..                ...              ...       ...
# 859             False            False     16.67
# 863              True             True     16.67
# 868             False            False     16.67
# 878             False            False     16.67
# 888              True            False     16.67
#
# [177 rows x 18 columns]
# Column: Cabin
#      PassengerId  Survived Pclass                                      Name  \
# 0              1     False      3                   Braund, Mr. Owen Harris
# 2              3      True      3                    Heikkinen, Miss. Laina
# 4              5     False      3                  Allen, Mr. William Henry
# 5              6     False      3                          Moran, Mr. James
# 7              8     False      3            Palsson, Master. Gosta Leonard
# ..           ...       ...    ...                                       ...
# 884          885     False      3                    Sutehall, Mr. Henry Jr
# 885          886     False      3      Rice, Mrs. William (Margaret Norton)
# 886          887     False      2                     Montvila, Rev. Juozas
# 888          889     False      3  Johnston, Miss. Catherine Helen "Carrie"
# 890          891     False      3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked  \
# 0      male  22.0      1      0         A/5 21171   7.2500   NaN        S
# 2    female  26.0      0      0  STON/O2. 3101282   7.9250   NaN        S
# 4      male  35.0      0      0            373450   8.0500   NaN        S
# 5      male   NaN      0      0            330877   8.4583   NaN        Q
# 7      male   2.0      3      1            349909  21.0750   NaN        S
# ..      ...   ...    ...    ...               ...      ...   ...      ...
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 890    male  32.0      0      0            370376   7.7500   NaN        Q
#
#      PassengerId_is_outlier  Age_is_outlier  SibSp_is_outlier  \
# 0                     False           False             False
# 2                     False           False             False
# 4                     False           False             False
# 5                     False           False             False
# 7                     False           False              True
# ..                      ...             ...               ...
# 884                   False           False             False
# 885                   False           False             False
# 886                   False           False             False
# 888                   False           False             False
# 890                   False           False             False
#
#      Parch_is_outlier  Fare_is_outlier  null_pct
# 0               False            False      8.33
# 2               False            False      8.33
# 4               False            False      8.33
# 5               False            False     16.67
# 7                True            False      8.33
# ..                ...              ...       ...
# 884             False            False      8.33
# 885              True            False      8.33
# 886             False            False      8.33
# 888              True            False     16.67
# 890             False            False      8.33
#
# [687 rows x 18 columns]
# Column: Embarked
#      PassengerId  Survived Pclass                                       Name  \
# 61            62      True      1                        Icard, Miss. Amelie
# 829          830      True      1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#         Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked  \
# 61   female  38.0      0      0  113572  80.0   B28      NaN
# 829  female  62.0      0      0  113572  80.0   B28      NaN
#
#      PassengerId_is_outlier  Age_is_outlier  SibSp_is_outlier  \
# 61                    False           False             False
# 829                   False            True             False
#
#      Parch_is_outlier  Fare_is_outlier  null_pct
# 61              False             True      8.33
# 829             False             True      8.33

# %%
print("Rows With More than a single null value in a row")
df.loc[df.isnull().sum(axis=1)>=2,:]
# Out:
# Rows With More than a single null value in a row
# Empty DataFrame
# Columns: [null_pct, time_spent_is_outlier, session_id_is_null, session_number_is_null, client_agent_is_null, device_details_is_null, date_is_null, purchased_is_null, added_in_cart_is_null, checked_out_is_null, time_spent_is_null]
# Index: []

# %%
df.columns
# Out:
# Index(['null_pct', 'time_spent_is_outlier', 'session_id_is_null',
#        'session_number_is_null', 'client_agent_is_null',
#        'device_details_is_null', 'date_is_null', 'purchased_is_null',
#        'added_in_cart_is_null', 'checked_out_is_null', 'time_spent_is_null'],
#       dtype='object')

# %%
df["null_pct"].value_counts()
# Out:
# 0.00     5269
# 11.11     160
# Name: null_pct, dtype: int64

# %%
df.drop("null_pct",axis=1,inplace=True)

# %% [markdown]
# ## Target Column Outlier

# %%
df["time_spent_is_outlier"].value_counts(normalize=True)*100
# Out:
# False    87.658869
# True     12.341131
# Name: time_spent_is_outlier, dtype: float64

# %%
df.query("time_spent_is_outlier==True").sample(10)
# Out:
#       time_spent_is_outlier  session_id_is_null  session_number_is_null  \
# 685                    True               False                   False
# 1774                   True               False                   False
# 3803                   True               False                   False
# 5051                   True               False                   False
# 3265                   True               False                   False
# 5129                   True               False                   False
# 3123                   True               False                   False
# 4962                   True               False                   False
# 747                    True               False                   False
# 3212                   True               False                   False
#
#       client_agent_is_null  device_details_is_null  date_is_null  \
# 685                  False                   False         False
# 1774                 False                   False         False
# 3803                 False                   False         False
# 5051                 False                   False         False
# 3265                 False                   False         False
# 5129                 False                   False         False
# 3123                 False                   False         False
# 4962                 False                   False         False
# 747                  False                   False         False
# 3212                 False                   False         False
#
#       purchased_is_null  added_in_cart_is_null  checked_out_is_null  \
# 685               False                  False                False
# 1774              False                  False                False
# 3803              False                  False                False
# 5051              False                  False                False
# 3265              False                  False                False
# 5129              False                  False                False
# 3123              False                  False                False
# 4962              False                  False                False
# 747               False                  False                False
# 3212              False                  False                False
#
#       time_spent_is_null
# 685                False
# 1774               False
# 3803               False
# 5051               False
# 3265               False
# 5129               False
# 3123               False
# 4962               False
# 747                False
# 3212               False

# %%
df.dtypes
# Out:
# time_spent_is_outlier     bool
# session_id_is_null        bool
# session_number_is_null    bool
# client_agent_is_null      bool
# device_details_is_null    bool
# date_is_null              bool
# purchased_is_null         bool
# added_in_cart_is_null     bool
# checked_out_is_null       bool
# time_spent_is_null        bool
# dtype: object

# %%
df.drop(["session_id","session_number"],axis=1,inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-21-ba73d5993b09> in <module>
# ----> 1 df.drop(["session_id","session_number"],axis=1,inplace=True)
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3995             level=level,
#    3996             inplace=inplace,
# -> 3997             errors=errors,
#    3998         )
#    3999
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3934         for axis, labels in axes.items():
#    3935             if labels is not None:
# -> 3936                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3937
#    3938         if inplace:
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors)
#    3968                 new_axis = axis.drop(labels, level=level, errors=errors)
#    3969             else:
# -> 3970                 new_axis = axis.drop(labels, errors=errors)
#    3971             result = self.reindex(**{axis_name: new_axis})
#    3972
#
# ~/opt/miniconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    5015         if mask.any():
#    5016             if errors != "ignore":
# -> 5017                 raise KeyError(f"{labels[mask]} not found in axis")
#    5018             indexer = indexer[~mask]
#    5019         return self.delete(indexer)
#
# KeyError: "['session_id' 'session_number'] not found in axis"

# %%
mapping = {"purchased":"bool","added_in_cart":"bool","checked_out":"bool","date":"dt_%Y-%m-%d","time_spent_is_outlier":"bool","client_agent_is_null":"bool"}

# %%
import json
with open('../intermediate_data/dtypes.json', 'w') as f:
    json.dump(mapping, f)

# %%
df.to_json("../intermediate_data/null_outlier_handled.json")
